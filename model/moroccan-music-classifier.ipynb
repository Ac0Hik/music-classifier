# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import librosa
import math
import json 
import matplotlib.pyplot as plt
import IPython
from random import randint
import math

#ml packages
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, models, Sequential
import statistics

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
path = '/kaggle/input/moroccan-music-data/MoroccanMusic'

genre_dict = {"gnawa":0,"chaabi":1,"andalusian":2, "rai":3, "imazighn":4, "rap":5 }

# %% [markdown]
# **Data Preprocessing + feature exctractiong**

# %%
def preprocess(dataset_path, num_mfcc=40, n_fft=2048, hop_length=512, num_segment=10):
    data = {'audio_path':[], "labels": [], "mfcc": []}
    sample_rate = 22050
    samples_per_segment = int(sample_rate * 30 / num_segment)
    
    for label_idx, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):
        if dirpath == dataset_path:
            continue
        dirname = os.path.basename(dirpath)
        print(dirname)
        lbl = genre_dict[dirname]
        for f in sorted(filenames):
            if not f.endswith('.wav'):
                continue
            if(f=="jazz.00054.wav"):
            # As librosa only read files <1Mb
              continue
            file_path = os.path.join(dirpath, f)
            
            try:
                y, sr = librosa.load(file_path, sr=sample_rate)
            except:
                continue
            try:
              for n in range(num_segment):
                 start_sample = samples_per_segment * n
                 end_sample = start_sample + samples_per_segment
                
                 mfcc = librosa.feature.mfcc(y=y[start_sample:end_sample], sr=sr, n_mfcc=40, n_fft=2048, hop_length = 512)

                 mfcc = mfcc.T
                 if len(mfcc) == math.ceil(samples_per_segment / hop_length):
                     data["audio_path"].append(file_path)
                     data["mfcc"].append(mfcc.tolist())
                     data["labels"].append(lbl)
            except:
                print(file_path + str(lbl))
                
      
    return data

# %%
data = preprocess(path)
# Out:
# rap
# /opt/conda/lib/python3.10/site-packages/librosa/core/spectrum.py:256: UserWarning: n_fft=2048 is too large for input signal of length=0
#   warnings.warn(
# rai
# chaabi
# gnawa
# imazighn
# andalusian

# %%
data["audio_path"][0], data["labels"][0]
# Out:
# ('/kaggle/input/moroccan-music-data/MoroccanMusic/rap/rap.00000.wav', 5)

# %% [markdown]
# **Save preprocessed data to disk**

# %%
data_df = pd.DataFrame(data)
data_df.to_csv('/kaggle/working/moroccanMusic_extracted_features.csv')

# %%
data = pd.read_csv('/kaggle/input/temp-files/moroccanMusic_extracted_features.csv')

# %% [markdown]
# **Ml part**

# %%
X = np.array(data["mfcc"], dtype=object)
X = np.asarray(X).astype('float32')
y = np.array(data["labels"])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
y_train[0]

# %%
np.unique(y_train)
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
input_shape= (X_train.shape[1],X_train.shape[2])
input_shape
# Out:
# (130, 40)

# %% [markdown]
# **Model**

# %%
classifier = Sequential()
classifier.add(layers.LSTM(64, input_shape=(input_shape[0], input_shape[1]), return_sequences=True))
classifier.add(layers.LSTM(64))
classifier.add(layers.Dense(64, activation='relu'))
classifier.add(layers.Dense(10, activation='softmax'))

# %%
import tensorflow as tf

# %%
optimizer = tf.keras.optimizers.Adam(lr=0.001)
classifier.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
classifier.summary()
classifier.fit(X_train, y_train, validation_data=(X_val,y_val), batch_size=32, epochs=60, verbose=2)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 130, 64)           26880
#
#  lstm_1 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 64,714
# Trainable params: 64,714
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/60
# 110/110 - 21s - loss: 1.4247 - accuracy: 0.4811 - val_loss: 1.0934 - val_accuracy: 0.6144 - 21s/epoch - 195ms/step
# Epoch 2/60
# 110/110 - 16s - loss: 0.9034 - accuracy: 0.6731 - val_loss: 0.8107 - val_accuracy: 0.7059 - 16s/epoch - 142ms/step
# Epoch 3/60
# 110/110 - 16s - loss: 0.7059 - accuracy: 0.7489 - val_loss: 0.8151 - val_accuracy: 0.7140 - 16s/epoch - 143ms/step
# Epoch 4/60
# 110/110 - 16s - loss: 0.6539 - accuracy: 0.7789 - val_loss: 0.7051 - val_accuracy: 0.7506 - 16s/epoch - 141ms/step
# Epoch 5/60
# 110/110 - 15s - loss: 0.5123 - accuracy: 0.8292 - val_loss: 0.6535 - val_accuracy: 0.7769 - 15s/epoch - 140ms/step
# Epoch 6/60
# 110/110 - 16s - loss: 0.5237 - accuracy: 0.8221 - val_loss: 0.5012 - val_accuracy: 0.8341 - 16s/epoch - 148ms/step
# Epoch 7/60
# 110/110 - 16s - loss: 0.3770 - accuracy: 0.8759 - val_loss: 0.5244 - val_accuracy: 0.8238 - 16s/epoch - 146ms/step
# Epoch 8/60
# 110/110 - 16s - loss: 0.3173 - accuracy: 0.8996 - val_loss: 0.4593 - val_accuracy: 0.8524 - 16s/epoch - 142ms/step
# Epoch 9/60
# 110/110 - 16s - loss: 0.3075 - accuracy: 0.8987 - val_loss: 0.3518 - val_accuracy: 0.8822 - 16s/epoch - 143ms/step
# Epoch 10/60
# 110/110 - 17s - loss: 0.3599 - accuracy: 0.8833 - val_loss: 0.3976 - val_accuracy: 0.8822 - 17s/epoch - 152ms/step
# Epoch 11/60
# 110/110 - 17s - loss: 0.2486 - accuracy: 0.9185 - val_loss: 0.4148 - val_accuracy: 0.8513 - 17s/epoch - 152ms/step
# Epoch 12/60
# 110/110 - 17s - loss: 0.1865 - accuracy: 0.9371 - val_loss: 0.2750 - val_accuracy: 0.8982 - 17s/epoch - 151ms/step
# Epoch 13/60
# 110/110 - 17s - loss: 0.1785 - accuracy: 0.9425 - val_loss: 0.3057 - val_accuracy: 0.9062 - 17s/epoch - 153ms/step
# Epoch 14/60
# 110/110 - 16s - loss: 0.1293 - accuracy: 0.9617 - val_loss: 0.2682 - val_accuracy: 0.9153 - 16s/epoch - 145ms/step
# Epoch 15/60
# 110/110 - 16s - loss: 0.1242 - accuracy: 0.9594 - val_loss: 0.3458 - val_accuracy: 0.8844 - 16s/epoch - 147ms/step
# Epoch 16/60
# 110/110 - 16s - loss: 0.1506 - accuracy: 0.9508 - val_loss: 0.2360 - val_accuracy: 0.9268 - 16s/epoch - 145ms/step
# Epoch 17/60
# 110/110 - 16s - loss: 0.1658 - accuracy: 0.9448 - val_loss: 0.3124 - val_accuracy: 0.9096 - 16s/epoch - 145ms/step
# Epoch 18/60
# 110/110 - 16s - loss: 0.1397 - accuracy: 0.9580 - val_loss: 0.3018 - val_accuracy: 0.9039 - 16s/epoch - 145ms/step
# Epoch 19/60
# 110/110 - 16s - loss: 0.1449 - accuracy: 0.9554 - val_loss: 0.2222 - val_accuracy: 0.9325 - 16s/epoch - 148ms/step
# Epoch 20/60
# 110/110 - 16s - loss: 0.0829 - accuracy: 0.9751 - val_loss: 0.2468 - val_accuracy: 0.9233 - 16s/epoch - 145ms/step
# Epoch 21/60
# 110/110 - 16s - loss: 0.0515 - accuracy: 0.9857 - val_loss: 0.2963 - val_accuracy: 0.9188 - 16s/epoch - 145ms/step
# Epoch 22/60
# 110/110 - 16s - loss: 0.0653 - accuracy: 0.9800 - val_loss: 0.3327 - val_accuracy: 0.8924 - 16s/epoch - 144ms/step
# Epoch 23/60
# 110/110 - 16s - loss: 0.0652 - accuracy: 0.9803 - val_loss: 0.2558 - val_accuracy: 0.9245 - 16s/epoch - 145ms/step
# Epoch 24/60
# 110/110 - 16s - loss: 0.0964 - accuracy: 0.9685 - val_loss: 0.2379 - val_accuracy: 0.9211 - 16s/epoch - 145ms/step
# Epoch 25/60
# 110/110 - 16s - loss: 0.0729 - accuracy: 0.9817 - val_loss: 0.3463 - val_accuracy: 0.9153 - 16s/epoch - 145ms/step
# Epoch 26/60
# 110/110 - 16s - loss: 0.0773 - accuracy: 0.9745 - val_loss: 0.2294 - val_accuracy: 0.9371 - 16s/epoch - 142ms/step
# Epoch 27/60
# 110/110 - 16s - loss: 0.0214 - accuracy: 0.9949 - val_loss: 0.2344 - val_accuracy: 0.9371 - 16s/epoch - 145ms/step
# Epoch 28/60
# 110/110 - 16s - loss: 0.0161 - accuracy: 0.9951 - val_loss: 0.2242 - val_accuracy: 0.9394 - 16s/epoch - 143ms/step
# Epoch 29/60
# 110/110 - 16s - loss: 0.0415 - accuracy: 0.9880 - val_loss: 0.2875 - val_accuracy: 0.9165 - 16s/epoch - 148ms/step
# Epoch 30/60
# 110/110 - 16s - loss: 0.0822 - accuracy: 0.9720 - val_loss: 0.2746 - val_accuracy: 0.9279 - 16s/epoch - 146ms/step
# Epoch 31/60
# 110/110 - 16s - loss: 0.0586 - accuracy: 0.9785 - val_loss: 0.2892 - val_accuracy: 0.9302 - 16s/epoch - 147ms/step
# Epoch 32/60
# 110/110 - 16s - loss: 0.0369 - accuracy: 0.9888 - val_loss: 0.2360 - val_accuracy: 0.9394 - 16s/epoch - 146ms/step
# Epoch 33/60
# 110/110 - 16s - loss: 0.0355 - accuracy: 0.9883 - val_loss: 0.2011 - val_accuracy: 0.9428 - 16s/epoch - 149ms/step
# Epoch 34/60
# 110/110 - 16s - loss: 0.0401 - accuracy: 0.9871 - val_loss: 0.2345 - val_accuracy: 0.9348 - 16s/epoch - 145ms/step
# Epoch 35/60
# 110/110 - 16s - loss: 0.0343 - accuracy: 0.9883 - val_loss: 0.1953 - val_accuracy: 0.9416 - 16s/epoch - 146ms/step
# Epoch 36/60
# 110/110 - 16s - loss: 0.0111 - accuracy: 0.9971 - val_loss: 0.1905 - val_accuracy: 0.9451 - 16s/epoch - 144ms/step
# Epoch 37/60
# 110/110 - 16s - loss: 0.0119 - accuracy: 0.9974 - val_loss: 0.2262 - val_accuracy: 0.9371 - 16s/epoch - 146ms/step
# Epoch 38/60
# 110/110 - 15s - loss: 0.0298 - accuracy: 0.9897 - val_loss: 0.1987 - val_accuracy: 0.9474 - 15s/epoch - 141ms/step
# Epoch 39/60
# 110/110 - 16s - loss: 0.0114 - accuracy: 0.9977 - val_loss: 0.2066 - val_accuracy: 0.9531 - 16s/epoch - 145ms/step
# Epoch 40/60
# 110/110 - 16s - loss: 0.0025 - accuracy: 0.9997 - val_loss: 0.2124 - val_accuracy: 0.9497 - 16s/epoch - 144ms/step
# Epoch 41/60
# 110/110 - 16s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2115 - val_accuracy: 0.9462 - 16s/epoch - 149ms/step
# Epoch 42/60
# 110/110 - 16s - loss: 9.2062e-04 - accuracy: 1.0000 - val_loss: 0.2045 - val_accuracy: 0.9531 - 16s/epoch - 142ms/step
# Epoch 43/60
# 110/110 - 17s - loss: 7.0096e-04 - accuracy: 1.0000 - val_loss: 0.2075 - val_accuracy: 0.9542 - 17s/epoch - 158ms/step
# Epoch 44/60
# 110/110 - 16s - loss: 5.8365e-04 - accuracy: 1.0000 - val_loss: 0.2112 - val_accuracy: 0.9542 - 16s/epoch - 145ms/step
# Epoch 45/60
# 110/110 - 16s - loss: 4.9363e-04 - accuracy: 1.0000 - val_loss: 0.2148 - val_accuracy: 0.9531 - 16s/epoch - 145ms/step
# Epoch 46/60
# 110/110 - 16s - loss: 4.2433e-04 - accuracy: 1.0000 - val_loss: 0.2177 - val_accuracy: 0.9565 - 16s/epoch - 148ms/step
# Epoch 47/60
# 110/110 - 17s - loss: 3.7186e-04 - accuracy: 1.0000 - val_loss: 0.2207 - val_accuracy: 0.9565 - 17s/epoch - 153ms/step
# Epoch 48/60
# 110/110 - 17s - loss: 3.2700e-04 - accuracy: 1.0000 - val_loss: 0.2231 - val_accuracy: 0.9542 - 17s/epoch - 153ms/step
# Epoch 49/60
# 110/110 - 17s - loss: 2.8906e-04 - accuracy: 1.0000 - val_loss: 0.2249 - val_accuracy: 0.9531 - 17s/epoch - 152ms/step
# Epoch 50/60
# 110/110 - 17s - loss: 2.5816e-04 - accuracy: 1.0000 - val_loss: 0.2271 - val_accuracy: 0.9565 - 17s/epoch - 153ms/step
# Epoch 51/60
# 110/110 - 17s - loss: 2.3075e-04 - accuracy: 1.0000 - val_loss: 0.2305 - val_accuracy: 0.9565 - 17s/epoch - 155ms/step
# Epoch 52/60
# 110/110 - 17s - loss: 2.0802e-04 - accuracy: 1.0000 - val_loss: 0.2335 - val_accuracy: 0.9531 - 17s/epoch - 153ms/step
# Epoch 53/60
# 110/110 - 16s - loss: 1.8810e-04 - accuracy: 1.0000 - val_loss: 0.2359 - val_accuracy: 0.9531 - 16s/epoch - 147ms/step
# Epoch 54/60
# 110/110 - 16s - loss: 1.7076e-04 - accuracy: 1.0000 - val_loss: 0.2387 - val_accuracy: 0.9531 - 16s/epoch - 148ms/step
# Epoch 55/60
# 110/110 - 16s - loss: 1.5522e-04 - accuracy: 1.0000 - val_loss: 0.2430 - val_accuracy: 0.9531 - 16s/epoch - 149ms/step
# Epoch 56/60
# 110/110 - 16s - loss: 1.4157e-04 - accuracy: 1.0000 - val_loss: 0.2451 - val_accuracy: 0.9531 - 16s/epoch - 146ms/step
# Epoch 57/60
# 110/110 - 16s - loss: 1.2915e-04 - accuracy: 1.0000 - val_loss: 0.2481 - val_accuracy: 0.9542 - 16s/epoch - 149ms/step
# Epoch 58/60
# 110/110 - 16s - loss: 1.1862e-04 - accuracy: 1.0000 - val_loss: 0.2512 - val_accuracy: 0.9542 - 16s/epoch - 145ms/step
# Epoch 59/60
# 110/110 - 16s - loss: 1.0878e-04 - accuracy: 1.0000 - val_loss: 0.2542 - val_accuracy: 0.9542 - 16s/epoch - 147ms/step
# Epoch 60/60
# 110/110 - 16s - loss: 9.9557e-05 - accuracy: 1.0000 - val_loss: 0.2582 - val_accuracy: 0.9542 - 16s/epoch - 145ms/step

# %%
train_loss, train_acc  = classifier.evaluate(X_train, y_train, batch_size=128)
# Out:
# 28/28 [==============================] - 4s 148ms/step - loss: 9.2864e-05 - accuracy: 1.0000

# %%
test_loss, test_acc  = classifier.evaluate(X_test, y_test, batch_size=128)
# Out:
# 12/12 [==============================] - 2s 137ms/step - loss: 0.2449 - accuracy: 0.9636

# %%
number_to_genre_dict = {0:"gnawa" , 1:"chaabi", 2:"andalusian", 3:"rai", 4:"imazighn", 5:"rap"}

# %% [markdown]
# **single predictions examples**

# %%
def print_class_name(classes):
    print(f'the predicted class is {number_to_genre_dict[statistics.mode(classes)]}')

# %%
def class_pred(classifier, file):  
    y, sr = librosa.load(file)
    oneSong = []
    for n in range(10):
        start_sample = 22050*3  * n
        end_sample = start_sample + 22050*3
                
        mfcc = librosa.feature.mfcc(y=y[start_sample:end_sample], sr=sr, n_mfcc=40, n_fft=2048, hop_length = 512)

        mfcc = mfcc.T
        
        if len(mfcc) == math.ceil( 22050*3 / 512 ):
                oneSong.append(mfcc.tolist())



    oneSong = np.array(oneSong, dtype=object)
    oneSong = nsong = np.asarray(oneSong).astype('float32')
    oneSong.shape

    prediction = classifier.predict(oneSong)

    classes_x =np.argmax(prediction,axis=1)
    return classes_x

# %%
myfile = '/kaggle/input/temp-files/Bob_MarleyEverythings_Gonna_Be_Alright.wav'
print_class_name(class_pred(classifier, myfile))
# Out:
# 1/1 [==============================] - 0s 66ms/step
# the predicted class is gnawa

# %% [markdown]
# **Save/load the model to/from disk**

# %%
# serialize model to JSON
model_json = classifier.to_json()
with open("Moroccanmodel.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
classifier.save_weights("Moroccanmodel.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
from keras.models import model_from_json
# load json and create model
json_file = open('/kaggle/working/Moroccanmodel.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("/kaggle/working/Moroccanmodel.h5")
print("Loaded model from disk")
